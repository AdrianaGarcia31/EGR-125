# %%
# !pip install pandas

# %%
import pandas as pd

# %%
#The index column make easy to look at values
weather = pd.read_csv('weather_data.csv',index_col = "DATE")

# %%
weather.head()
# Out:
#                 STATION                                            NAME  ACMH  \
# DATE
# 1960-04-01  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# 1960-04-02  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# 1960-04-03  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# 1960-04-04  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# 1960-04-05  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
#
#             ACSH  AWND  FMTM  FRGT  PGTM  PRCP  PSUN  ...  WT13  WT14  WT15  \
# DATE                                                  ...
# 1960-04-01   NaN   NaN   NaN   NaN   NaN  0.03   NaN  ...   NaN   NaN   NaN
# 1960-04-02   NaN   NaN   NaN   NaN   NaN  1.36   NaN  ...   NaN   NaN   NaN
# 1960-04-03   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 1960-04-04   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# ...

# %%
#This code will count the number of missing values in each column. 
#apply() applies the isnull function to each element on the Data Frame

weather.apply(pd.isnull).sum()
# Out:
# STATION        0
# NAME           0
# ACMH       11340
# ACSH       11337
# AWND        8149
# FMTM       12671
# FRGT       22775
# PGTM        5982
# PRCP         107
# PSUN       22774
# SNOW          53
# SNWD          96
# TAVG       16157
# TMAX          44
# TMIN          46
# TSUN       21819
# WDF1       11340
# WDF2       12654
# WDF5       12717
# WDFG       10747
# WESD       16510
# WSF1       11339
# WSF2       12654
# WSF5       12716
# WSFG       10747
# WT01       12507
# WT02       21347
# WT03       20902
# WT04       22377
# WT05       22377
# WT06       22469
# WT07       22664
# WT08       17822
# WT09       22687
# WT10       22773
# WT11       22753
# WT13       19996
# WT14       21910
# WT15       22710
# WT16       15289
# WT17       22670
# WT18       21629
# WT19       22763
# WT21       22591
# WT22       22713
# WV03       22710
# dtype: int64

# %%
weather.columns
# Out:
# Index(['STATION', 'NAME', 'ACMH', 'ACSH', 'AWND', 'FMTM', 'FRGT', 'PGTM',
#        'PRCP', 'PSUN', 'SNOW', 'SNWD', 'TAVG', 'TMAX', 'TMIN', 'TSUN', 'WDF1',
#        'WDF2', 'WDF5', 'WDFG', 'WESD', 'WSF1', 'WSF2', 'WSF5', 'WSFG', 'WT01',
#        'WT02', 'WT03', 'WT04', 'WT05', 'WT06', 'WT07', 'WT08', 'WT09', 'WT10',
#        'WT11', 'WT13', 'WT14', 'WT15', 'WT16', 'WT17', 'WT18', 'WT19', 'WT21',
#        'WT22', 'WV03'],
#       dtype='object')

# %%
len(weather.columns)
# Out:
# 46

# %%
#shape[0] gives the number of rows and shape[1] gives the number of columns
#To know which columns have missing values in percentage
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.497893
# ACSH       0.497761
# AWND       0.357789
# FMTM       0.556331
# FRGT       0.999956
# PGTM       0.262645
# PRCP       0.004698
# PSUN       0.999912
# SNOW       0.002327
# SNWD       0.004215
# TAVG       0.709387
# TMAX       0.001932
# TMIN       0.002020
# TSUN       0.957982
# WDF1       0.497893
# WDF2       0.555585
# WDF5       0.558351
# WDFG       0.471856
# WESD       0.724886
# WSF1       0.497849
# WSF2       0.555585
# WSF5       0.558307
# WSFG       0.471856
# WT01       0.549131
# WT02       0.937259
# WT03       0.917720
# WT04       0.982482
# WT05       0.982482
# WT06       0.986521
# WT07       0.995083
# WT08       0.782490
# WT09       0.996092
# WT10       0.999868
# WT11       0.998990
# WT13       0.877942
# WT14       0.961978
# WT15       0.997102
# WT16       0.671277
# WT17       0.995346
# WT18       0.949640
# WT19       0.999429
# WT21       0.991877
# WT22       0.997234
# ...

# %%
#Using the data documentation and from analyzing the percentage. I will choose some of them for my new weather data
new_weather = weather[["PRCP","SNOW","SNWD","TMAX","TMIN"]].copy()

# %%
new_weather.head()
# Out:
#             PRCP  SNOW  SNWD  TMAX  TMIN
# DATE
# 1960-04-01  0.03   0.0   0.0  71.0  47.0
# 1960-04-02  1.36   0.0   0.0   NaN   NaN
# 1960-04-03   NaN   0.0   0.0   NaN   NaN
# 1960-04-04   NaN   0.0   0.0  70.0   NaN
# 1960-04-05  1.75   0.0   0.0  48.0  42.0

# %%
#Now we can see again the missing values for these 6 information
new_weather.apply(pd.isnull).sum()/new_weather.shape[0]
# Out:
# PRCP    0.004698
# SNOW    0.002327
# SNWD    0.004215
# TMAX    0.001932
# TMIN    0.002020
# dtype: float64

# %%
new_weather[pd.isnull(new_weather["PRCP"])]
# Out:
#             PRCP  SNOW  SNWD  TMAX  TMIN
# DATE
# 1960-04-03   NaN   0.0   0.0   NaN   NaN
# 1960-04-04   NaN   0.0   0.0  70.0   NaN
# 1960-04-22   NaN   0.0   0.0   NaN   NaN
# 1960-05-01   NaN   0.0   0.0   NaN   NaN
# 1960-05-09   NaN   0.0   0.0  66.0  45.0
# ...          ...   ...   ...   ...   ...
# 1963-02-21   NaN   0.0   0.0  44.0  15.0
# 1963-02-22   NaN   0.0   0.0  21.0   8.0
# 1963-02-23   NaN   0.0   0.0  34.0   5.0
# 1963-02-24   NaN   0.0   0.0  38.0  29.0
# 1963-02-25   NaN   0.0   0.0  47.0  19.0
#
# [107 rows x 5 columns]

# %%
start_date = '1960-04-03'
end_date  = '1960-05-09'
new_weather.loc[start_date:end_date]
# Out:
#             PRCP  SNOW  SNWD  TMAX  TMIN
# DATE
# 1960-04-03   NaN   0.0   0.0   NaN   NaN
# 1960-04-04   NaN   0.0   0.0  70.0   NaN
# 1960-04-05  1.75   0.0   0.0  48.0  42.0
# 1960-04-06  0.00   0.0   0.0  52.0  34.0
# 1960-04-07  0.00   0.0   0.0  63.0  34.0
# 1960-04-08  0.00   0.0   0.0  64.0  41.0
# 1960-04-09  0.00   0.0   0.0   NaN   NaN
# 1960-04-10  0.00   0.0   0.0   NaN   NaN
# 1960-04-11  0.00   0.0   0.0  59.0  25.0
# 1960-04-12  0.00   0.0   0.0  75.0  49.0
# 1960-04-13  0.00   0.0   0.0  79.0  36.0
# 1960-04-14  0.00   0.0   0.0  87.0  46.0
# 1960-04-15  0.00   0.0   0.0  86.0  53.0
# 1960-04-16  0.00   0.0   0.0   NaN   NaN
# 1960-04-17  0.00   0.0   0.0   NaN   NaN
# 1960-04-18  0.30   0.0   0.0  58.0  50.0
# 1960-04-19  0.00   0.0   0.0  61.0  33.0
# 1960-04-20  0.00   0.0   0.0  71.0  35.0
# 1960-04-21  0.00   0.0   0.0  76.0  56.0
# 1960-04-22   NaN   0.0   0.0   NaN   NaN
# 1960-04-23  0.00   0.0   0.0   NaN   NaN
# 1960-04-24  0.00   0.0   0.0   NaN   NaN
# ...

# %%
new_weather.head()
# Out:
#             PRCP  SNOW  SNWD  TMAX  TMIN
# DATE
# 1960-04-01  0.03   0.0   0.0  71.0  47.0
# 1960-04-02  1.36   0.0   0.0   NaN   NaN
# 1960-04-03   NaN   0.0   0.0   NaN   NaN
# 1960-04-04   NaN   0.0   0.0  70.0   NaN
# 1960-04-05  1.75   0.0   0.0  48.0  42.0

# %%
new_weather["PRCP"].value_counts()
# Out:
# 0.00    15371
# 0.01      748
# 0.02      454
# 0.03      347
# 0.04      296
#         ...
# 2.63        1
# 2.61        1
# 2.11        1
# 2.13        1
# 2.18        1
# Name: PRCP, Length: 277, dtype: int64

# %%
new_weather["SNOW"].value_counts()
# Out:
# 0.0     22088
# 0.2        70
# 0.3        49
# 0.1        45
# 0.4        32
#         ...
# 11.4        1
# 10.5        1
# 8.3         1
# 9.1         1
# 7.7         1
# Name: SNOW, Length: 92, dtype: int64

# %%
new_weather["SNWD"].value_counts()
# Out:
# 0.0     21652
# 1.0       242
# 2.0       191
# 3.0       146
# 4.0        95
# 5.0        57
# 6.0        47
# 1.2        45
# 7.0        28
# 8.0        27
# 3.1        21
# 9.0        18
# 3.9        15
# 10.0       11
# 15.0        9
# 5.1         8
# 18.0        8
# 12.0        8
# 11.0        6
# 5.9         5
# 20.0        4
# 7.1         4
# 13.0        3
# 14.0        3
# 7.9         3
# 16.0        3
# 19.0        3
# 21.0        3
# 22.0        2
# 24.0        2
# 17.0        1
# 25.0        1
# 26.0        1
# 23.0        1
# 28.0        1
# 27.2        1
# 25.2        1
# 18.1        1
# 16.1        1
# 14.2        1
# 9.8         1
# Name: SNWD, dtype: int64

# %%
new_weather["TMAX"].value_counts()
# Out:
# 85.0     543
# 84.0     536
# 83.0     535
# 80.0     520
# 87.0     511
#         ...
# 13.0       1
# 11.0       1
# 10.0       1
# 6.0        1
# 105.0      1
# Name: TMAX, Length: 98, dtype: int64

# %%
new_weather["TMIN"].value_counts()
# Out:
#  29.0    489
#  63.0    486
#  28.0    486
#  66.0    481
#  30.0    464
#         ...
# -14.0      1
# -16.0      1
# -18.0      1
# -17.0      1
#  79.0      1
# Name: TMIN, Length: 94, dtype: int64

# %%
new_weather["PRCP"] = new_weather["PRCP"].fillna(0)

# %%
new_weather.head()
# Out:
#             PRCP  SNOW  SNWD  TMAX  TMIN
# DATE
# 1960-04-01  0.03   0.0   0.0  71.0  47.0
# 1960-04-02  1.36   0.0   0.0   NaN   NaN
# 1960-04-03  0.00   0.0   0.0   NaN   NaN
# 1960-04-04  0.00   0.0   0.0  70.0   NaN
# 1960-04-05  1.75   0.0   0.0  48.0  42.0

# %%
new_weather["SNOW"] = new_weather["SNOW"].fillna(0)

# %%
new_weather["SNWD"] = new_weather["SNWD"].fillna(0)

# %%
new_weather[pd.isnull(new_weather["TMAX"])]
# Out:
#             PRCP  SNOW  SNWD  TMAX  TMIN
# DATE
# 1960-04-02  1.36   0.0   0.0   NaN   NaN
# 1960-04-03  0.00   0.0   0.0   NaN   NaN
# 1960-04-09  0.00   0.0   0.0   NaN   NaN
# 1960-04-10  0.00   0.0   0.0   NaN   NaN
# 1960-04-16  0.00   0.0   0.0   NaN   NaN
# 1960-04-17  0.00   0.0   0.0   NaN   NaN
# 1960-04-22  0.00   0.0   0.0   NaN   NaN
# 1960-04-23  0.00   0.0   0.0   NaN   NaN
# 1960-04-24  0.00   0.0   0.0   NaN   NaN
# 1960-04-30  0.26   0.0   0.0   NaN   NaN
# 1960-05-01  0.00   0.0   0.0   NaN   NaN
# 1960-05-07  0.00   0.0   0.0   NaN   NaN
# 1960-05-14  0.00   0.0   0.0   NaN   NaN
# 1960-05-15  0.00   0.0   0.0   NaN   NaN
# 1960-05-20  0.00   0.0   0.0   NaN   NaN
# 1960-05-21  0.00   0.0   0.0   NaN   NaN
# 1960-05-22  0.00   0.0   0.0   NaN   NaN
# 1960-05-28  0.00   0.0   0.0   NaN   NaN
# 1960-05-29  0.00   0.0   0.0   NaN   NaN
# 1960-05-30  2.65   0.0   0.0   NaN   NaN
# 1960-06-04  0.00   0.0   0.0   NaN   NaN
# 1960-06-05  0.00   0.0   0.0   NaN   NaN
# ...

# %%
new_weather.dtypes
# Out:
# DATE     object
# PRCP    float64
# SNOW    float64
# SNWD    float64
# TMAX    float64
# TMIN    float64
# dtype: object

# %%
new_weather.index
# Out:
# Index(['1960-04-01', '1960-04-02', '1960-04-03', '1960-04-04', '1960-04-05',
#        '1960-04-06', '1960-04-07', '1960-04-08', '1960-04-09', '1960-04-10',
#        ...
#        '2024-01-16', '2024-01-17', '2024-01-18', '2024-01-19', '2024-01-20',
#        '2024-01-21', '2024-01-22', '2024-01-23', '2024-01-24', '2024-01-25'],
#       dtype='object', name='DATE', length=22776)

# %%
#Turn our index into a datetime index
new_weather.index = pd.to_datetime(new_weather.index)

# %%
new_weather.index
# Out:
# DatetimeIndex(['1960-04-01', '1960-04-02', '1960-04-03', '1960-04-04',
#                '1960-04-05', '1960-04-06', '1960-04-07', '1960-04-08',
#                '1960-04-09', '1960-04-10',
#                ...
#                '2024-01-16', '2024-01-17', '2024-01-18', '2024-01-19',
#                '2024-01-20', '2024-01-21', '2024-01-22', '2024-01-23',
#                '2024-01-24', '2024-01-25'],
#               dtype='datetime64[ns]', name='DATE', length=22776, freq=None)
